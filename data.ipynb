# %% [markdown]
# # UNDERSTANDING DATASET

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3  15 Civilians Killed In Single US Airstrike Hav...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# 2                             Consortiumnews.com
# 3                                Jessica Purkiss
# 4                                 Howard Portnoy
# ...                                          ...
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 0      House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1      Ever get the feeling your life circles the rou...      0
# 2      Why the Truth Might Get You Fired October 29, ...      1
# 3      Videos 15 Civilians Killed In Single US Airstr...      1
# 4      Print \nAn Iranian woman has been sentenced to...      1
# ...                                                  ...    ...
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# 20798  NATO, Russia To Hold Parallel Exercises In Bal...      1
# 20799    David Swanson is an author, activist, journa...      1
#
# [20800 rows x 5 columns]

# %% [markdown]
# ### Dataset Columns for Fake News Detection
#
# 1. **id** - Unique identifier for each news article.
# 2. **title** - Title or headline of the news article.
# 3. **author** - Author of the article.
# 4. **text** - Full text content of the article.
# 5. **label** - Target variable indicating the authenticity of the article (e.g., 0 for fake, 1 for real).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
df.describe()
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
df.columns
# Out:
# Index(['id', 'title', 'author', 'text', 'label'], dtype='object')

# %%
df.count()
# Out:
# id        20800
# title     20242
# author    18843
# text      20761
# label     20800
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# 1    10413
# 0    10387
# Name: label, dtype: int64

# %%
df.author.unique()
# Out:
# array(['Darrell Lucus', 'Daniel J. Flynn', 'Consortiumnews.com', ...,
#        'D. Samuelson', 'Judge Andrew Napolitano',
#        'Michael J. de la Merced and Rachel Abrams'], dtype=object)

# %%
df.shape
# Out:
# (20800, 5)

# %%
# Filter authors whose label is 1
authors_label_1 = df[df['label'] == 1]['author'].unique().tolist()
authors_label_1
# Out:
# ['Darrell Lucus',
#  'Consortiumnews.com',
#  'Jessica Purkiss',
#  'Howard Portnoy',
#  nan,
#  'Amando Flavio',
#  'Jason Ditz',
#  'AnotherAnnie',
#  'Starkman',
#  'The Doc',
#  'Ira Helfand',
#  'Amanda Shea',
#  'greanfinisher .',
#  'b',
#  'Alexandria Laredo',
#  'Gordon Duff, Senior Editor',
#  'Lance Schuttler',
#  'Dairy✓ᵀᴿᵁᴹᴾ',
#  'Madeline',
#  'M.R. Islam',
#  'Anonymous Coward (UID 12781064)',
#  'Truth Broadcast Network',
#  'Admin',
#  'Jason Easley',
#  'Chris Black',
#  'Ivan the Stakhanovets',
#  'Redflag Newsdesk',
#  'Steve Sailer',
#  'Scott Osborn',
#  'Heather Callaghan',
#  'Kayla Brandon',
#  'Mac Slavo',
#  'Natural News Editors',
#  'Activist Post',
#  'The Anti-Media',
#  'Amy Moreno',
#  'admin',
#  'Anonymous',
#  'Contributing Author',
#  'Eric Striker',
#  'SeekSearchDestory',
#  'David Stockman',
#  'wmw_admin',
#  'Editor',
#  'beforeitsnews.com',
#  'Geoffrey Grider',
#  'T Steelman',
#  'Zero Hedge',
#  'The European Union Times',
#  'Andrew Anglin',
#  'Colin Taylor',
#  'Ari Lieberman',
#  'Nathan J. Robinson',
#  'Dikran Arakelian (noreply@blogger.com)',
#  'Whitney Webb',
#  'David Swanson',
#  'James Fulford',
#  'Arnaldo Rodgers',
#  'Guest',
#  'runsinquicksand',
#  'RT',
#  'BareNakedIslam',
#  'IWB',
#  'DSG',
#  'Twain Yobra',
#  'Raffie',
#  'FaceSpace',
#  'The Daily Sheeple',
#  'Tim King',
#  'Dawn Parabellum',
#  'Sausage Machine',
#  'PhilSilversGhost',
#  'Angela Borozna',
#  'Xavi Puig',
#  'Shepard Ambellas',
#  'Paul Fassa',
#  'Dr. Patrick Slattery',
#  'Thomas Sowell',
#  'Jenna Leigh Richardson',
#  'noreply@blogger.com (Der Postillon)',
#  'pcr3',
#  'Eric Zuesse.',
#  'Sean Adl-Tabatabai',
#  'WakingTimes',
#  'Justen Charters',
#  'Anonymous Coward (UID 11897093)',
#  'Roger Aronoff',
#  'beersession',
#  'Amanda Froelich',
#  'Pamela Bofferding',
#  'VDARE.com Reader',
#  'Jafe Arnoldski (noreply@blogger.com)',
#  'voltairenet.org',
#  'Beau Albrecht',
#  'Zach Cartwright',
#  'King World News',
#  'Editorial',
#  'Neal Gabler',
#  'SGT',
#  'Redacción',
#  'Hugh Esco',
#  'Cliff Kincaid',
#  'Dave Hodges',
#  'Mohsen Abdelmoumen',
#  'Middle East Eye',
#  'Natalie Dickinson',
#  'Anonymous Coward (UID 73268493)',
#  'Stephen Lendman',
#  'Daniel Greenfield',
#  'Glen Ford',
#  'Christina Sarich',
#  'Graywolf',
#  'The Mind Unleashed',
#  'Alex Ansary',
#  'Henry Wolff',
#  'John Falkenberg',
#  'Svetlana Arkhangelskaya, special to RBTH',
#  'Carey Wedler',
#  'J.E. Dyer',
#  'Isaac Davis',
#  'Eddy Lavine',
#  'Colm Williamson',
#  'Adan Salazar',
#  'Davis',
#  'VC',
#  'Robert Rich',
#  'Patrick Bond',
#  'Nathanial Mauka',
#  'Carol Adl',
#  'The Saker',
#  'gortex',
#  'Jeremy R. Hammond',
#  'Leigh Haugh',
#  'Jane Bailey',
#  'Remy Porter',
#  'Author',
#  'Citizen Satirist',
#  'teleSUR',
#  'Pakalert',
#  'curriec',
#  'noreply@blogger.com (Alexander Light)',
#  'Ernest Partridge',
#  'Gillian',
#  'Jason Ditz | Antiwar.com',
#  'A. Griffee',
#  'Baxter Dmitry',
#  'Buck Rogers',
#  '-NO AUTHOR-',
#  'Cassandra Fairbanks',
#  'beemasters',
#  'Dr. Marsha Coleman-Adebayo',
#  'shelby andrews',
#  'Redlist Renegade',
#  'Tomás Fuentes',
#  'reasoning with facts',
#  'South Front',
#  'Arnold Monteverde (noreply@blogger.com)',
#  'Don Anthony Dillon',
#  'Kaitlyn Stegall',
#  'Rowan Wolf',
#  'Michael Krieger',
#  'John Kaminski',
#  'Stephanie Kuklish',
#  'Anonymous Coward (UID 19747754)',
#  'skylynn jones',
#  'Architecture is More Than a Clever Arrangement of Bricks: This Man Transforms it Into a Healing Process - New Earth Media',
#  'Elina St-Onge',
#  'EdJenner',
#  'Dr. Majid Rafizadeh',
#  'SloMoe',
#  'Flying Table-fan',
#  'Quest',
#  'newsbiscuit editorial team',
#  'Elliot Bougis',
#  'Bob Adelmann',
#  'Victoria Taft',
#  'Vladimir Putin',
#  'Chris "Kikila" Perrin',
#  'Bernie Suarez',
#  'Ariel Noyola Rodríguez',
#  'Warren Mass',
#  'Grant Stern',
#  'Pat Buchanan',
#  'Claire Bernish',
#  'Sayer Ji',
#  'RT на русском',
#  'Poke Staff',
#  'Joe Martino',
#  'Dan',
#  'Elisabeth Parker',
#  'Kelen M',
#  'José Tirado',
#  'Ryan Banister',
#  'Timmy',
#  'Blitzkrieg622',
#  'Tatiana Covington',
#  'Margaret Griffis',
#  'RBR!',
#  'Pepe Escobar',
#  'Sarah D.',
#  'Sunday Devotional: The whole Universe is as a grain — Fellowship of the Minds | kommonsentsjane',
#  'IHTT',
#  'Jerri-Lynn Scofield',
#  'Josh',
#  'stevew',
#  'V Saxena',
#  'informationclearinghouse.info',
#  'Jared Taylor',
#  'John W. Whitehead',
#  'VNN',
#  'Daily Bell Staff',
#  'Rex Kwon Do  ✓ᵈᵉᵖˡᵒʳᵃᵇˡᵉ',
#  'mitch51',
#  'Admin - Orissa',
#  'Lisa Tanner',
#  'Moron',
#  'The Common Constitutionalist',
#  'cargosquid',
#  'Blanche Benson',
#  'kalli',
#  'The Conservative Millennial',
#  'newsguy76',
#  'Hefficide',
#  'TFPP Writer',
#  'Dudleydooright',
#  'Posted At Pm On October',
#  'Hemp: Readdressing Cannabis – kuebiko.co',
#  'Xcathdra',
#  'Doc Chaos',
#  'CatoCensored',
#  'shorty',
#  'Wilmot Proviso',
#  'TASS',
#  'Roosh Valizadeh',
#  'Daisy Luther',
#  'Gerry McBride',
#  'Onan Coca',
#  'Manlio Dinucci',
#  'Lily Dane',
#  'Ben Tanosborn',
#  'Kantzveldt',
#  'J. D. Heyes',
#  'Groucho Marxist',
#  'Teapolicy',
#  'Chris Menahan',
#  'Michael Greger M.D. FACLM',
#  'Usa News Flash',
#  'Matt Forney',
#  'Inessa S (noreply@blogger.com)',
#  'Captain Craptek',
#  'GPD',
#  'Sane Responder',
#  '# 1 NWO Hatr',
#  '4 of the Best Kinds of Milk That Aren’t Dairy – Collective Evolution | APG Editorial',
#  'Michael Hayne',
#  'James Kirkpatrick',
#  'Ian',
#  'dailouk',
#  'gatorengineer',
#  'Sven Longshanks',
#  'Mike Rivero',
#  'Joel Wickwire',
#  'Sergey Gladysh',
#  'IT Ninja',
#  'Robert Parry',
#  'Jing Jin',
#  'martin wright',
#  'Vicki Batts',
#  'David G. Brown',
#  'James Petras',
#  'thefitgirl',
#  'Heavy',
#  'rooster1957',
#  'Mike Adams',
#  'Clock Crasher',
#  'Brianna Acuesta',
#  'Bruce Thornton',
#  'Countrybunkererd',
#  'Scott',
#  'Kike García',
#  'RT.com',
#  'wtromp@operamail.com (WT)',
#  'Rebecca Diserio',
#  'Pamela Geller',
#  'Gustavo Arellano',
#  'Wrenfoe',
#  'braindiseasecalledliberalism',
#  'Misty',
#  'Thomas Faddis',
#  'Miskondukt',
#  'tokyowashi (noreply@blogger.com)',
#  'Enjoykin4',
#  'Carrie MacDonald',
#  'Mark Bowytz',
#  'jose',
#  'Debbie Menon',
#  'TheFineReport.com',
#  'Rmuse',
#  'Selwyn Duke',
#  'Mike Farrell',
#  'jim',
#  'Eric Margolis',
#  'Sara Vallone',
#  'Corbett',
#  'Kyle Trouble',
#  'MM',
#  'Paul Craig Roberts',
#  'stevor',
#  'LU Staff',
#  'Jenny Heth',
#  'Isabelle Z.',
#  'Adam Garrie',
#  'Anonymous Coward (UID 26968733)',
#  'Staff Writer',
#  'Amy Goodrich',
#  'Danny F. Quest',
#  'Eric Zuesse',
#  'David Rives',
#  'Doug P.',
#  'Joe Sammut',
#  'Hugh Everett',
#  'Bravenewmalden',
#  'Eric Walberg',
#  'Sarah Jones',
#  'Rahul Manchanda, Esq.',
#  'RIA Novosti',
#  'Alex Christoforou',
#  'Bob Livingston',
#  'ironmansouth',
#  'No Author',
#  'Waking Times',
#  'Dan Wright',
#  'Guest Post',
#  'Tracy Blake',
#  'Shirley Barnett',
#  'Anonymous Coward (UID 47910020)',
#  'Emily Pont',
#  'Steve Watson',
#  'peter kropotkin',
#  'Chris Roberts',
#  'Roqayah Chamseddine',
#  'Jordan Baranowski',
#  'Lee Adler',
#  'Pat Cocivera',
#  'Eric Botena',
#  'HILLARY CLINTON’S TIES TO ISIS SUPPORTERS | osmanisnin',
#  'Peter Koenig',
#  'Man',
#  'Brian Sonenstein',
#  'redlucy',
#  'Daniel Haiphong',
#  'Ken Knabb',
#  'Shawn Helton',
#  'Jameson Parker',
#  'The Free Thought Project',
#  'Ben Marquis',
#  'Anonymous Coward (UID 73270245)',
#  'Theresa Crouse',
#  'Steve Byas',
#  'Ike Mclean',
#  'Alisha Rich',
#  'Vladimir Golstein',
#  'Nicole Higman',
#  'Isiah Holmes | The Fifth Column',
#  'Christy Lee Parker',
#  'Charles Goyette',
#  'Lambert Strether',
#  'Michael Snyder',
#  'Bryan K. Bullock',
#  'SGTSTEDENKO2',
#  'Russia Today (Rusia)',
#  'Infowars Nightly News',
#  'Andrew Bradford',
#  'Andy Green',
#  'Iron Sheik',
#  'Natalie Dailey',
#  'Светлана Якн',
#  'Charles Hugh Smith',
#  'Oxbridge',
#  'C.E. Dyer',
#  'Reid Mene',
#  'Antiwar',
#  'Topher Frankenberg',
#  'The Guardian',
#  'JimQ',
#  'Patsy Mendoza McBee',
#  'Genosse Dummkopf',
#  'Ariana',
#  'Cherese Jackson',
#  'Barbara Nimri Aziz',
#  'Harris',
#  'Entertainment and Movie reviews with tips on how to get Website Traffic and Make Money Online.',
#  'Larry Kelley',
#  'Auntie Lulu',
#  'Regan Pifer',
#  'Douglass Price',
#  'Andrea Germanos | Common Dreams',
#  'WashingtonsBlog',
#  'Adalia Woodbury',
#  'Frank Salvato',
#  'Michael E. Telzrow',
#  'Ron Yahaloms',
#  'Shannon Barber',
#  'Anteater',
#  'avandagriff',
#  'April Hamlin',
#  'Jonathan Lee',
#  'Aaron Kesel',
#  'Rich Ledergerber',
#  'Paul Joseph Watson',
#  'Kim Smith',
#  'جنگ ارزی آمریکا علیه ایران / مورد مطالعاتی سال 1390 - کدآمایی',
#  'Daniel Barker',
#  'Gaye Levy',
#  'ahtribune.com',
#  'jakespoon',
#  'Yves Smith',
#  'kryptodyne',
#  'watchmannonthewall',
#  'Joe Wolverton, II, J.D.',
#  'Dr. Robert Owens',
#  'floosy',
#  'weins.a',
#  'Guest Author',
#  'Ashwin Kumar',
#  'Dom the Conservative',
#  'ZeroHedge.com',
#  'Justin Green',
#  'Shari Savage',
#  'EV',
#  'fundamentaly flawed humanity',
#  'Joe Clark',
#  'Jeremiah Johnson',
#  'K. Campbell',
#  'David Schultz',
#  'Joe from MassPrivateI',
#  'RBTH',
#  'Влада Крутова',
#  'Nikolaj Schewtschenko',
#  'Tyler Durden',
#  'JAMES FRIDAY',
#  'Carl Herman',
#  'George',
#  'Email Protected',
#  'Robert Gehl',
#  'Are black holes fountains of creation? – The Conscious Mind',
#  'Maryaha',
#  'MaryAlice Parks',
#  'REALdeal',
#  'John Derbyshire',
#  'Ian Greenhalgh',
#  'Alexa Erickson',
#  'More Ammo',
#  'Patrick Cockburn',
#  'Matthew Sison',
#  'Larsen Halleck',
#  'Paddy Maclachlan',
#  'GrahamSeibert',
#  'Raven Clabough',
#  'Margaret Kimberley',
#  'Frank Scott',
#  'Kevin Barrett',
#  'Amanda',
#  'RBC, Anton Feinberg',
#  'Ronnie Allen',
#  'Kevin Boyle',
#  'Staff',
#  'Dyanne Weiss',
#  'Wolfenotes',
#  'Dawn Perlmutter',
#  'David Costa',
#  'Robert J Burrowes',
#  'Jack Heart',
#  'Allison Vincent',
#  'Kevin Gosztola',
#  'Dr. Serge Gregoire',
#  'Arch Stanton',
#  'besnook',
#  'Lou Colagiovanni',
#  'Greg P.',
#  'ActivistPost',
#  'Without Malice',
#  'Deflation Market',
#  'Jacob G. Hornberger',
#  'Rafiq',
#  'Brandon Turbeville',
#  'Tom Cahill',
#  'CoastalMaineBird',
#  'carmody.j',
#  'mcshane',
#  'Sean Colarossi',
#  'Gary Leupp',
#  'Vanessa Frank',
#  'A.D.H.D. NATION: HOW BIG PHARMA CREATED THE A.D.H.D. EPIDEMIC - Black Barth',
#  'John Wight',
#  'Robert Koehler',
#  'Mark Guay',
#  'RT en español',
#  'Robert Fisk',
#  'Larry Elder',
#  'John Doe',
#  'Rebel yell',
#  'IBXNJ',
#  'BlueShaman',
#  'GrayRider',
#  'exposethebad',
#  'Times Live',
#  'Damon Morgan',
#  'Tennessee Dan',
#  'Brandon Tuberville',
#  'The Funny Farmer',
#  'Lasha Darkmoon',
#  'Hunter Schwarz',
#  'Paul Edwards',
#  'Michael S. Rozeff',
#  'Usapoliticsnow Admin',
#  'Adrian Bamforth',
#  'Steven Broiles',
#  'Jim in Littleton',
#  'KootenayCoyote',
#  'Lisa Bonanno',
#  'Patrick Cleburne',
#  'Virginia Kruta',
#  'Oysteria',
#  'Tess Pennington',
#  'Phonics Monkey',
#  'Prissy Holly',
#  'K',
#  'Caleb R. Newton',
#  'Donna',
#  'F. William Engdahl',
#  'Europa-News',
#  'MarkinLA',
#  'Grownmangrumbles',
#  'Tim Brown',
#  'AnAverageJoe',
#  'PatriotRising',
#  'Christine Branch',
#  'Andrew Schuricht',
#  'Harry Hibbs',
#  'greenanon',
#  'FedUpWithWelfareStates',
#  'Deplorable Revbo™',
#  'ColdTrifecta',
#  'Ellen Brodsky',
#  'Joachim Hagopian',
#  'Sam_Spade',
#  'Martha Rosenberg',
#  'Anonymous Coward (UID 73270427)',
#  'DaRAGE',
#  'WhiteDawn',
#  'Jonas E. Alexis',
#  '10 Habits That Will Make Your Life Easier &amp; More Peaceful - Wellness Solutions',
#  'Daniel Thomas',
#  'Julius Hubris',
#  'Bryan William Myers',
#  'Piper McGowin',
#  'Andrew P. Napolitano',
#  'John Helmer',
#  'John Pilger',
#  'hqanon',
#  'Toby',
#  'xuenchen',
#  'DCG',
#  'Sam J.',
#  'sf4t9rfan',
#  'Gareth Porter',
#  'Reader',
#  'James Hall',
#  'The Rundown Live',
#  'Anonymous: World War 3 Is On The Horizon (In 2016) – Collective Evolution',
#  'Ann Coulter',
#  'Arshad Khan',
#  'Amnesty International',
#  'TNUGA',
#  'Dissidentvoice',
#  'OK',
#  'Murray Dobbin',
#  'Joanne Leon',
#  'Robert',
#  'What are the harsh life lessons everyone should learn in their 20s? • BLOGNOTION',
#  'Jhayla Walls',
#  'Boris Egorov',
#  'AFP',
#  'Michael T. Klare',
#  'Jon Anthony',
#  'Lauren McCauley | Common Dreams',
#  'Joan Workman',
#  'JB',
#  'jhamilton',
#  'Daniel McAdams',
#  'برنامه ریزی ضمیر ناخوداگاه',
#  'ctwatcher✓ᵛᵉʳᶦᶠᶦᵉᵈ',
#  'Bob Unruh',
#  'Llewellyn H. Rockwell, Jr.',
#  'Wahab Raofi',
#  'Israel Shamir',
#  'Allen L Roland, PhD',
#  'D-MAN',
#  'tapatio',
#  'Danny Gold',
#  'Dml Daily',
#  'Ness',
#  'CJ Hopkins',
#  'Gearóid Ó Colmáin',
#  "Hey, That's Mildly Adequate",
#  'information security architect',
#  'Harold Hughes',
#  'Shelby Kellin',
#  'These Lifestyle Choices Lower Your Breast Cancer Risk, Even If You Are Genetically Predisposed To It - Everything you can imagine is real',
#  'Investigative Historian Eric Zuesse Is The Author',
#  'Pat Hynes',
#  'Sartre',
#  'John F. McManus',
#  'James Bovard',
#  'Michael Collins',
#  'C. Mitchell Shaw',
#  'EmployedMillenial',
#  'Alan',
#  'mjazzguitar',
#  'DavidSwanson',
#  'PeaceFrog',
#  'Osman Soysal',
#  'searcherfortruth',
#  'Anonymous Coward (UID 58307359)',
#  'Smitch',
#  'True Activist',
#  'jack nichols',
#  '10 Presidents &amp; Politicians Who Told Us That A “Secret Government” Controls The World &amp; What They Said - Upside Down Media',
#  'Benjamin Garland',
#  'Letsbereal',
#  'Relampago Furioso',
#  'marlene',
#  'Tom Winter (noreply@blogger.com)',
#  'C S Krishna',
#  'Herbert Mujica Rojas',
#  'Press TV',
#  'Tubal Cain',
#  'special to RBTH, Sakari Linden',
#  'Edmondo Burr',
#  'beeeyotch',
#  'Bruce A. Dixon',
#  'Brock Robinson',
#  'Captain Community',
#  'Be Glad U Had Obama (UID 58059507)',
#  'Carl_Herman',
#  'Kit Daniels',
#  'Ариэль Нойола Родригес',
#  'Jenn Ryan',
#  'Joe Narly!',
#  'Les Visible',
#  'Ron Paul',
#  'Peter Lee',
#  'Jews Did World War and Open Borders – aladdinsmiraclelamp',
#  'Michael Brown',
#  'eforce',
#  'Mint Press News Desk',
#  'Dominic Waghorn',
#  'Danny Haiphong',
#  'Dr. Eowyn',
#  'john smith',
#  '500 Year Old Map Discovered Shatters The Official History Of The Human Race',
#  'a different chris',
#  'harry naasz',
#  'Andrew Meyer',
#  'Marisa Martin',
#  'Dave Hunt',
#  'Dan Jones',
#  'Patrick Krey',
#  'righteous',
#  'Anonymous Coward (UID 73270620)',
#  "World War 3 News 2016: Anonymous Declares WW3 'on the Horizon'",
#  'Caty McClure',
#  'Michael Tennant',
#  'azzmador',
#  'Bolofia',
#  'truckjunkie',
#  'Mr. Wendal',
#  'Herb Swanson',
#  'Тьерри Мейсан',
#  'Michael',
#  'Dottie Langhals',
#  '10 Movies That Could Change Your Understanding Of Life - Upside Down Media',
#  'Mike Whitney',
#  'Smoking Mirrors',
#  'Interesting article about ADHD diagnoses » Hypnotherapy by Jenny',
#  'Алла Белькевич',
#  'Bleikr Sound',
#  'ladylove',
#  'matafuchs',
#  'ezekiel22',
#  'Matt Peppe',
#  'Vandita',
#  'Cory Doctorow',
#  'Andrew Levine',
#  'Mike Dan',
#  'Tom Engelhardt',
#  "The Cat's Vagina (Nasty Woman)",
#  'knukles',
#  'Orwellian_Dilemma',
#  'MaxRockatansky33',
#  'BBC targets children to promote the transgender propaganda — Fellowship of the Minds | childreninshadow.wordpress.com | CHILDREN IN SHADOW ::: CHILDREN IN WAR',
#  'Stronghorse',
#  'sebastien Provencher',
#  'T. Mohr',
#  "Kit O'Connell",
#  'Seth Connell',
#  'Becky Akers',
#  'Kevin Michael Grace',
#  'darkbake',
#  'Paul Gottfried',
#  'Jon Hall',
#  'Infarction',
#  'Squudge',
#  'Professional Human',
#  'Andrew Napolitano',
#  'Karl Denninger',
#  'The Most Important Concepts The Manosphere Taught Me',
#  'Henry Shivley',
#  'Mike Miller',
#  'Anna Grouzdeva',
#  'Леонтина Литвинова',
#  'National Public Radio',
#  'Is This What You Think They Would Look Like? Supposed Pictures of Real Extraterrestrials - New Earth Media',
#  'pascalmolineaux',
#  'Christian Zionist',
#  'Sharon Jeanguenat',
#  'Du er, hvad du læser. | Dyslexic workers',
#  'Rhonda Gilmore',
#  'Javi Ramos',
#  'jim james',
#  'Jason Bermas',
#  'Fiona Miller',
#  'Matt Agorist',
#  'Anonymous Activist',
#  'smith.j',
#  'HazyHotDog',
#  'Rich Hultén',
#  'Jason Howerton',
#  'vlawde',
#  'Teotihuacan',
#  'Spifflove',
#  'Dwdan',
#  'fungirl91',
#  'Barracuda Brigade',
#  'Scott Buss',
#  'hawkmo99',
#  'Slomotrainwreck',
#  'Patrick Carr',
#  'Julie Fidler',
#  'Louis Yako',
#  'Dr. Edward F. Group III',
#  'LuCy X (UID 12702162)',
#  'Alex Cooper',
#  'Bettie',
#  'Anonymous Coward (UID 18807137)',
#  'Claudio Grass',
#  'Douglas W. Rodrigues',
#  'Sacco Vandal',
#  'Hawkeyerightsmart',
#  'Mikael Thalen',
#  'parum imperium',
#  'Peeple',
#  'Anonymous Coward (UID 73271258)',
#  'Kedzie',
#  'TennesseeRedDog',
#  'DL',
#  'The Earth Child Admin',
#  'Alex Newman',
#  '1777',
#  'hivdatingsites',
#  'Parker Lee',
#  'E. A. Costa',
#  'Ethan A. Huff, staff writer',
#  'Thomas C. Mountain',
#  'Amy Bell',
#  'Bob Reinhard',
#  'André du Pôle',
#  'Justin Sawchuk',
#  'Michael Ware',
#  'YouKnowWho',
#  'ari9999',
#  'Profusion',
#  'whyamIhere',
#  'Barry Soetoro, Esq',
#  'Craig Murphy',
#  'Michael Sebastian',
#  'Terresa Monroe-Hamilton',
#  'Shae Weatherall',
#  'K Balakumar',
#  'The Paper Ostrich',
#  'Rainman',
#  'Wes Williams',
#  'National Geographic',
#  'Tileus',
#  'Prudence Hill',
#  'OllieP',
#  'lenore.lee',
#  'MosheShekelRod88',
#  'JohnSmith2016',
#  'Mick',
#  'David Gutierrez, staff writer',
#  'Red Ice',
#  'Paul Street',
#  'lostinnm',
#  'Patrick J. Buchanan',
#  'Kai Kieferle',
#  'Fed Up',
#  'Steve__Jacobson',
#  'ken williams',
#  'The Sleuth Journal',
#  'Martin',
#  'Luis Miranda',
#  'Catherine Shakdam',
#  'Nellie Bailey and Glen Ford',
#  'Ryan McMaken',
#  'V. Saxena',
#  'Dan Glazebrook',
#  'Bill White',
#  'Mike Adams, NaturalNews Editor',
#  'George Zapo',
#  'GetReal4U2',
#  'Is This What You Think They Would Look Like? Supposed Pictures of Real Extraterrestrials – Collective Evolution',
#  'Matthew Bernstein',
#  'Joe Kovacs',
#  'Matt Hill',
#  'Laura Carlsen',
#  'Paulus',
#  'Elijah Johnson',
#  'Lisa Smith',
#  'AramZS',
#  'theantediluvian',
#  'Baran Hines',
#  'Jay Syrmopoulos',
#  'Cigarette_Smoking_Man',
#  'Ron',
#  'Anonymous Coward (UID 73270906)',
#  'Branko Mali',
#  'samar pahwa',
#  'hsun85',
#  'Fernando Costilla',
#  'James Tracy',
#  'Andrew',
#  'Frankie',
#  'Glenn47',
#  'AFRICA-NEWS',
#  'Jon Rappoport',
#  'Christopher David',
#  'Sputnik News',
#  'Linh Dinh',
#  'Extinction Protocol',
#  'David Yearsley',
#  'American News',
#  'JimBob',
#  'kia',
#  'Svetlana Arkhangelskaïa',
#  'Yessenia Funes',
#  '10 Shocking Facts About Society That We Absurdly Accept As Normal – Digital Flow',
#  'Brian',
#  'Justin Raimondo',
#  'Kantucky',
#  'Steve smith',
#  'Ruby Rowell',
#  'Clare Bernish',
#  'NeverSurrender',
#  'Rev. Peter M. J. Stravinskas, Ph.D., S.T.D.',
#  'Sputnik',
#  'Lisa Blake Bilinski',
#  'Евстахий Стахович',
#  'Jane Chastain',
#  'Neo-Pepe',
#  'Suresh Subrahmanyan',
#  'Erik Rush',
#  'Srikanth',
#  'Michael W. Chapman',
#  'digangi.s',
#  'Жанна Ивченко',
#  'Robert Dodge',
#  'Gomerblog Team',
#  'carewemust',
#  'Kike Garc A',
#  'LN Buzz Team',
#  'Justin Puck',
#  'phillips.m',
#  'Lisa Beach',
#  'Ronald Nelson',
#  'Brett T.',
#  'Kilgoar',
#  'Will Harper',
#  'Scientists Find A Plant That Could Treat Diabetes &amp; Kill Cancer Cells – Collective Evolution | SFO',
#  'John Patriot',
#  'James Michael',
#  'The Moscow Times',
#  'What Aloe Vera Does In Your Body: Why Egyptians Called It The Plant Of Immortality | My Blog',
#  'Philip A Farruggio',
#  'Victoria Richardson',
#  'Mae',
#  'AZU',
#  'Rossi Herbert',
#  'Suzy Kassem',
#  'Horst Frohlich',
#  'Butler Shaffer',
#  'JENO',
#  'Oleg Jegorow',
#  'Joe',
#  'Andrew Mullins',
#  'Paul Gottinger and Ken Klippenstein',
#  'Buck Bundy (UID 73107416)',
#  'Ignatius',
#  'Craig Ward',
#  'Vic Pittman',
#  'Corey Savage',
#  'Ideas Time',
#  'Sabine',
#  'Michelle Malkin',
#  'Rit Varriale',
#  'Hans Bader',
#  'Makia Freeman',
#  'Pleezdeez',
#  'para kazanmak',
#  'Why Do People Become Cuckservatives?',
#  'OlallaNicolasa',
#  'Shane Ashton',
#  'major major maj...',
#  'Prepper Website',
#  'Contributed Daily News Bin Staff',
#  'Jim Hightower',
#  'Richard Baehr',
#  'peggie gor',
#  'Brandy Mocanu',
#  'Proud American',
#  'A. Maren',
#  'Capt. Quantrill-deplorable SOB',
#  'Tempus t Fugit',
#  'Anonymous: There Is No One Way To Live On This Planet, But We Can Be Harmonious – Collective Evolution',
#  'Monica Sortland',
#  'Melkulangara Bhadrakumar',
#  'Alexey Mosko, Evgenia Mosko',
#  'recrisp',
#  'David Howard',
#  'L.J. Devon, Staff Writer',
#  'Artist',
#  'Brenda Walker',
#  'Settling in and visiting Cholula | Matt in Mexico',
#  'czynik',
#  'Jörg Guido Hülsmann',
#  'Eligio Abellera',
#  'Harry Abrams',
#  'Ed Krayewski',
#  "Aer O'Head",
#  'MarciaTheMurkyMuse🌠 Variegated',
#  'Hy Feiber',
#  'Janet Davenport',
#  'Jynxster',
#  'Jethro',
#  'Horace G. Campbell',
#  'Yanira Farray',
#  'Greg Freeman',
#  'Jonathan Cook',
#  'JD Salinger',
#  'SUPREMEMASTER',
#  'Joseph Farah',
#  'Craazee8',
#  'Dane Wigington',
#  'KD7ONE',
#  'cartier bracelet repliques',
#  'william ketly',
#  'Rosemary Hansen',
#  'Gregor Eisenstein',
#  'Dr. Stoyan Sarg',
#  'Hitlery_4_Dictator',
#  'Kathy',
#  'kliguy38',
#  'Kyle Becker',
#  'Miss Marple',
#  '19 Documentaries That Will Have An Impact On Your Life | Coffs Coast Health Club',
#  'Bill',
#  'Clinton Election Cheating: Will Trump Muster The Courage To Catcall Democrat Disqualification? – moralmatters.org',
#  'Dr. Glaucomflecken',
#  'Joseph Mercola',
#  'Jon Bowne',
#  'Philip Giraldi',
#  'Fred Reed',
#  'Ray McGovern',
#  'An Infographic Showing What Male Privilege Really Looks Like',
#  'Current Concerns (Switzerland)',
#  'Peter Brimelow',
#  'Lara Starr',
#  'Egon von Greyerz',
#  'aroamingcatholicny',
#  'Stephen Yearwood',
#  'Caroline Glick',
#  'William Brandon Shanley',
#  'Swetlana Archangelskaja',
#  'GrinNBarrett',
#  'Sarah Pappalardo',
#  'John Whitehead | The Rutherford Institute',
#  'Bill Sardi',
#  'jgordon',
#  'John Federico',
#  ...]

# %%
# Filter authors whose label is 0
authors_label_0 = df[df['label'] == 0]['author'].unique().tolist()
authors_label_0
# Out:
# ['Daniel J. Flynn',
#  'Daniel Nussbaum',
#  'Alissa J. Rubin',
#  nan,
#  'Megan Twohey and Scott Shane',
#  'Aaron Klein',
#  'Chris Tomlinson',
#  'Jack Williams',
#  'Michael Corkery and Stacy Cowley',
#  'Jeff Poor',
#  'Jerome Hudson',
#  'Pam Key',
#  'Donald G. McNeil Jr. and Pam Belluck',
#  'Aaron Klein and Ali Waked',
#  'Jim Dwyer',
#  'Mark Landler',
#  'Ian Hanchett',
#  'Steven Erlanger',
#  'Clifford Krauss',
#  'Leslie Picker, Danny Hakim and Michael J. de la Merced',
#  'Andrew Higgins',
#  'AWR Hawkins',
#  'Aaron E. Carroll',
#  'Dr. Susan Berry',
#  'Katie Rogers',
#  'Ian Mason',
#  'Jim Rutenberg, Ben Protess and Emily Steel',
#  'Brian X. Chen',
#  'Virginia Hale',
#  'Nate Church',
#  'Jeff Gordinier',
#  'Neil Irwin',
#  'Kenneth Chang and Sewell Chan',
#  'A. O. Scott',
#  'Kristina Wong',
#  'Jeremy W. Peters',
#  'Jacey Fortin',
#  'Brett Anderson',
#  'Jane Perlez',
#  'Josh Katz',
#  'Andrea Kannapell and Sandra Stevenson',
#  'Breitbart London',
#  'Nicholas Kulish, Vivian Yee, Caitlin Dickerson, Liz Robbins, Fernanda Santos and Jennifer Medina',
#  'Niraj Chokshi and Liam Stack',
#  'Jack Healy',
#  'Amanda Hess',
#  'Mike Birbiglia',
#  'Nicholas Casey and Patricia Torres',
#  'Breitbart News',
#  'Edwin Mora',
#  'Katherine Rodriguez',
#  'Vivian Yee',
#  'Tara Siegel Bernard',
#  'Matt Richtel',
#  'Nicholas Confessore and Rachel Shorey',
#  'Joel B. Pollak',
#  'Michael Patrick Leahy',
#  'Warner Todd Huston',
#  'Dylan Gwinn',
#  'John Koblin',
#  'Michael J. de la Merced',
#  'Jeré Longman',
#  'Ian Austen',
#  'Jon Pareles',
#  'Glenn Thrush, Kate Kelly and Maggie Haberman',
#  'Michael Forsythe and Chris Buckley',
#  'Dennis Overbye',
#  'Mujib Mashal',
#  'Trent Baker',
#  'Farhad Manjoo',
#  'Nick Corasaniti and Maggie Haberman',
#  'Ben Kew',
#  'Victor Mather, Doug Mills and Chang W. Lee',
#  'Jason Horowitz',
#  'Binyamin Appelbaum',
#  'Julie Hirschfeld Davis',
#  'Jonathan Soble',
#  'Christopher D. Shea',
#  'Adelle Nazarian',
#  'Declan Walsh',
#  'Wesley Morris',
#  'Carl Zimmer',
#  'Anne Barnard and Karam Shoumali',
#  'Gretchen Reynolds',
#  'Sopan Deb',
#  'Robert Draper',
#  'Eric Lipton, Charlie Savage and Michael S. Schmidt',
#  'Lizette Alvarez',
#  'Bob Price',
#  'Adam Shaw',
#  'David Waldstein',
#  'Jonathan Weisman, Eric Lichtblau and Charlie Savage',
#  'Jennifer Medina',
#  'Tony Lee',
#  'Sarah Lyall',
#  'John Hayward',
#  'Mark Mazzetti, Jeffrey Gettleman and Eric Schmitt',
#  'Alan Blinder',
#  'Eduardo Porter',
#  'Christopher Mele',
#  'Jim Rutenberg',
#  'Helene Cooper',
#  'Robert Frank and Karl Russell',
#  'Michael Corkery',
#  'Lucas Nolan',
#  'Andrew Ross Sorkin',
#  'Steph Yin',
#  'Paul Mozur',
#  'Mark Landler and Michael D. Shear',
#  'Penny Starr',
#  'Dana Thomas',
#  'Ashley Parker and David M. Herszenhorn',
#  'Elizabeth Paton',
#  'Mark Leibovich',
#  'Alan Rappeport',
#  'Declan Walsh and Nour Youssef',
#  'Sharon Harrigan',
#  'Carl Hulse, Julie Hirschfeld Davis, Alan Rappeport and Maggie Haberman',
#  'Breitbart Tech',
#  'Graham Bowley',
#  'Jess Bidgood, Alan Blinder and Jonathan M. Katz',
#  'The New York Times Magazine',
#  'Matthew E. May',
#  'Karen Workman',
#  'Melissa Eddy',
#  'Karen Crouse',
#  'Dan Kois',
#  'Emma G. Fitzsimmons',
#  'Nate Cohn',
#  'Rick Gladstone',
#  'Alex Williams',
#  'Peter S. Goodman',
#  'Monica Davey',
#  'Yamiche Alcindor',
#  'Charlie Spiering',
#  'Rick Rojas and J. David Goodman',
#  'Michael Paulson',
#  'Julie Hirschfeld Davis and Mark Landler',
#  'Ryan Saavedra',
#  'Isabel Kershner',
#  'Gardiner Harris, John Schwartz, Jackie Calmes and Jonathan Martin',
#  'Robert Pear and Michael D. Shear',
#  'Michael Wines',
#  'Ashley Parker',
#  'Charles McDermid',
#  'Lana Shadwick',
#  'Michelle Moons',
#  'Brett Cole',
#  'Aya Cash',
#  'Michael Forsythe',
#  'Maggie Haberman',
#  'Katie McHugh',
#  'Anemona Hartocollis',
#  'Michael D. Shear, Maggie Haberman and Glenn Thrush',
#  'The New York Times',
#  'Jonah Engel Bromwich and Sandra Stevenson',
#  'Liam Deacon',
#  'Bob Morris',
#  'Vanessa Friedman',
#  'Robert J. Marlow',
#  'Robert Pear and Jonathan Martin',
#  'Kimiko De Freytas-Tamura',
#  'Jeff Sommer',
#  'Gardiner Harris',
#  'John Otis',
#  'Mike Isaac',
#  'Scott Cacciola',
#  'Adam Goldman, Eric Lichtblau and Matt Apuzzo',
#  'Sydney Ember',
#  'Matthew Boyle',
#  'Tejal Rao',
#  'Christine Hauser',
#  'Sean Moran',
#  'Ben Hubbard',
#  'Pam Belluck',
#  'Mark Bittman',
#  'Karen Zraick and Sandra Stevenson',
#  'Kenneth Chang',
#  'Patrick McGeehan',
#  'Charlie Nash',
#  'Sheryl Gay Stolberg',
#  'Neil Munro',
#  'Felipe Villamor',
#  'Michael Kimmelman',
#  'Oliver JJ Lane',
#  'N. R. Kleinfield',
#  'Tom Ciccotta',
#  'Dwight Garner',
#  'James Verini',
#  'T Magazine',
#  'Ted Loos',
#  'J. David Goodman and William Neuman',
#  'Nate Chinen',
#  'Jacey Fortin and Jeffrey Gettleman',
#  'Chriss W. Street',
#  'Niraj Chokshi, Daniel Victor and Sewell Chan',
#  'Susan Chira',
#  'Lela Moore and Sona Patel',
#  'David Tanis',
#  'Gina Kolata',
#  'Pamela Druckerman',
#  'Noel Murray',
#  'James Poniewozik',
#  'Matthieu Aikins',
#  'Patrick Healy',
#  'Dave Itzkoff',
#  'Michael D. Shear',
#  'Ben Rawlence',
#  'Michael Barbaro',
#  'Thomas D. Williams, Ph.D.',
#  'Keith Bradsher',
#  'Trip Gabriel',
#  'Tyler Hicks',
#  'Michael Wilson',
#  'Mike McPhate',
#  'Frances Martel',
#  'Zach Schonbrun',
#  'David E. Sanger',
#  'Irina Aleksander',
#  'Geeta Anand and Hari Kumar',
#  'John Carney',
#  'Anne Barnard and Nick Cumming-Bruce',
#  'Alan Blinder and Richard Fausset',
#  'Stephen Castle and Steven Erlanger',
#  'Matthew Rosenberg',
#  'Karen Workman and Merrill D. Oliver',
#  'Dan Riehl',
#  'Nicholas Fandos',
#  'Reed Abelson',
#  'Alessandra Stanley',
#  'Cinthia Ritchie',
#  'Daniel Redmond',
#  'Brooks Barnes',
#  'Adam Nagourney and Henry Fountain',
#  'Steve Lohr',
#  'Matt Flegenheimer',
#  'Elaine Glusac',
#  'Amanda Taub',
#  'Michael D. Shear, Julie Hirschfeld Davis and Maggie Haberman',
#  'Catherine Saint Louis',
#  'Stephen Castle',
#  'Patrick Kingsley and Alissa J. Rubin',
#  'Margalit Fox',
#  'Niraj Chokshi',
#  'Shaila Dewan and Richard A. Oppel Jr.',
#  'Liam Stack',
#  'Paul Vitello',
#  'Lee Stranahan',
#  'Jennifer Senior',
#  'Juliet Macur',
#  'Katie Benner',
#  'Mike Ma',
#  'Nick Wingfield',
#  'Claire Cain Miller',
#  'Jeffrey Gettleman',
#  'Sam Roberts',
#  'Maggie Haberman and Alexander Burns',
#  'William Grimes',
#  'Conor Dougherty',
#  'Annie Correal',
#  'Breitbart Jerusalem',
#  'James B. Stewart',
#  'Jess Bidgood',
#  'Hilarie M. Sheets',
#  'Scott Shane and Andrew E. Kramer',
#  'Richard C. Paddock and Rick Gladstone',
#  'Merrill Hope',
#  'Joe Coscarelli',
#  'Coral Davenport',
#  'Eric Lichtblau',
#  'Noah Weiland',
#  'Jonathan Martin and Patrick Healy',
#  'Jonah Engel Bromwich',
#  'Noam Scheiber',
#  'Michael S. Schmidt, Eric Lipton and Charlie Savage',
#  'Jonah Engel Bromwich and Liam Stack',
#  'Simon Romero',
#  'Shivani Vora',
#  'Wai Moe, Mike Ives and Saw Nang',
#  'Daniel Victor',
#  'Noah Remnick',
#  'Karen Zraick and Lisa Iaboni',
#  'Neil Genzlinger',
#  'The Associated Press',
#  'Benoît Morenne',
#  'John Binder',
#  'Ildefonso Ortiz',
#  'Max Fisher',
#  'Lucas Peterson',
#  'Brad Spurgeon',
#  'Richard A. Friedman',
#  'Neil W. McCabe',
#  'Manohla Dargis',
#  'Paul Sullivan',
#  'Zachary Woolfe',
#  'Omar Al-Jawoshy and Sewell Chan',
#  'Hawes Spencer and Ben Sisario',
#  'Karen Workman and Sandra Stevenson',
#  'Glenn Thrush and Jonathan Martin',
#  'Alan Blinder and Kevin Sack',
#  'Carl Hulse',
#  'Jack Montgomery',
#  'Robin Pogrebin',
#  'Michelle Innis',
#  'Ken Belson',
#  'Alex Vadukul',
#  'Maggie Haberman, Matthew Rosenberg and Glenn Thrush',
#  'Falih Hassan, Tim Arango and Omar Al-Jawoshy',
#  'Matthew Rosenberg and Adam Goldman',
#  'Charlie Savage',
#  'Amanda House',
#  'Edward Wong',
#  'Somini Sengupta, Michael R. Gordon and Anne Barnard',
#  'Michael Wilson, Samantha Schmidt and Sarah Maslin Nir',
#  'Jon Caramanica',
#  'Ceylan Yeginsu and Rukmini Callimachi',
#  'Richard Fausset',
#  'Jay H. Lehr, Ph.D.',
#  'Somini Sengupta',
#  'Motoko Rich',
#  'Sapna Maheshwari',
#  'Annie Murphy Paul',
#  'Sarah Maslin Nir',
#  'Justin Wolfers',
#  'Alexander Burns',
#  'Ildefonso Ortiz and Brandon Darby',
#  'Lorne Manly',
#  'Benjamin Hoffman',
#  'Dan Barry',
#  'Katharine Q. Seelye',
#  'Richard Pérez-Peña',
#  'Maggie Haberman, Ashley Parker, Jeremy W. Peters and Michael Barbaro',
#  'Jennifer Schuessler',
#  'Stephen Castle and Sewell Chan',
#  'Tim Arango',
#  'Jonathan Martin and Alexander Burns',
#  'Julie Hirschfeld Davis, Christopher Drew, Nicholas Fandos and Jeremy W. Peters',
#  'Julia Preston',
#  'Ben Rothenberg',
#  'Randy Kennedy',
#  'John Eligon and Patrick McGee',
#  'Richard Fausset and Trip Gabriel',
#  'Finn Cohen',
#  'Scott Reyburn',
#  'Michael D. Shear and Michael R. Gordon',
#  'Alan Schwarz',
#  'Cartel Chronicles',
#  'Alan Wong',
#  'Karam Shoumali and Ben Hubbard',
#  'Dionne Searcey',
#  'Prashant S. Rao',
#  'Michael S. Schmidt',
#  'David E. Sanger and Anne Barnard',
#  'David Segal',
#  'Choe Sang-Hun',
#  'Kim Severson',
#  'Nicholas Casey',
#  'Alexander Burns and Mitch Smith',
#  'Stephanie Rosenbloom',
#  'Kirk Johnson',
#  'Michael D. Shear and Matthew Rosenberg',
#  'Jawad Sukhanyar',
#  'Jason Zinoman',
#  'Eric Lipton and Susanne Craig',
#  'Ian Fisher',
#  'Philip Galanes',
#  'Richard Fausset and Alan Blinder',
#  'Yamiche Alcindor and Matt Flegenheimer',
#  'Niki Kitsantonis',
#  'Hannah Olivennes',
#  'Eric Schmitt',
#  'Alexandra Alter',
#  'Kristina Wong &amp Alex Clark',
#  'Chris Horton',
#  'Jon Pareles, Jon Caramanica and Nate Chinen',
#  'Rachel L. Swarns',
#  'Simon Romero and Andrew Jacobs',
#  'Tyler Kepner',
#  'Virgil',
#  'Kate Taylor',
#  'Nate Schweber',
#  'Abby Goodnough and Sabrina Tavernise',
#  'Nicholas St. Fleur',
#  'Jeremy Egner',
#  'Donna Rachel Edmunds',
#  'Steve Eder and Megan Twohey',
#  'John Williams',
#  'Daisuke Wakabayashi and Sapna Maheshwari',
#  'Remy Tumin',
#  'Jason Horowitz and Yamiche Alcindor',
#  'Carl Richards',
#  'Susan Dominus',
#  'Charles Isherwood',
#  'James Glanz',
#  'Jack Healy and Kirk Johnson',
#  'Harvey Araton',
#  'Sinead O’Shea',
#  'Thomas Kaplan and Glenn Thrush',
#  'Victor Mather',
#  'Benedict Carey',
#  'David E. Sanger and Rick Gladstone',
#  'Anahad O’Connor',
#  'Ken Klukowski',
#  'Gardiner Harris and David E. Sanger',
#  'Farah Stockman and J. David Goodman',
#  'Anna Dubenko',
#  'Larry Rohter',
#  'Alexandra S. Levine',
#  'Katie Hafner',
#  'Bryan Denton and Michael R. Gordon',
#  'Jim Yardley',
#  'Jan Hoffman',
#  'Eric Lipton and Binyamin Appelbaum',
#  'Jessica Silver-Greenberg and Michael Corkery',
#  'Russell Goldman',
#  'Nick Corasaniti and Azam Ahmed',
#  'Patrick Boehler',
#  'Charles V. Bagli',
#  'Jennifer Steinhauer',
#  'Peter Baker',
#  'Nick Corasaniti',
#  'Neal E. Boudette',
#  'Cara Buckley',
#  'Julie Hirschfeld Davis and Maggie Haberman',
#  'Sabrina Tavernise',
#  'Michael Winerip, Michael Schwirtz and Robert Gebeloff',
#  'Martin Fackler',
#  'Jonathan Mahler and Matt Flegenheimer',
#  'Victoria Friedman',
#  'Landon Thomas Jr.',
#  'Robert Pear',
#  'Ben Hubbard and Hwaida Saad',
#  'Manny Fernandez',
#  'Michael Winerip and Michael Schwirtz',
#  'Andrew E. Kramer',
#  'Karen Zraick',
#  'Michael Cieply',
#  'Liz Spayd',
#  'J. David Goodman',
#  'Rick Rojas',
#  'Mujib Mashal and Fahim Abed',
#  'Andrea Kannapell and Lisa Iaboni',
#  'Mark O’Connell',
#  'Bill Pennington',
#  'Mike Ives',
#  'Barbara E. Murphy',
#  'Jennifer Steinhauer and Matt Flegenheimer',
#  'Richard Sandomir',
#  'Ezra Dulis',
#  'Felipe Villamor and Mike Ives',
#  'Richard Fausset, Alan Blinder and John Eligon',
#  'William J. Broad and David E. Sanger',
#  'Brooks Barnes and Amy Qin',
#  'Rukmini Callimachi',
#  'Robert Lipsyte',
#  'Thomas Fuller',
#  'Anne Barnard',
#  'Rosie Schaap',
#  'Milan Schreuer',
#  'Quentin Hardy',
#  'Jack Ewing',
#  'Benjamin Weiser, Nick Corasaniti and Maggie Haberman',
#  'Eric Schmitt and Michael R. Gordon',
#  'Melissa Clark',
#  'Craig S. Smith',
#  'Deborah Danan',
#  'Ken Belson and Jim Dwyer',
#  'Marc Tracy',
#  'Andrew Higgins, Mike McIntire and Gabriel J.X. Dance',
#  'Alex Swoyer',
#  'Jason Farago',
#  'Simon Kent',
#  'Jonah Engel Bromwich and Daniel Victor',
#  'Eric Lipton and Matt Flegenheimer',
#  'Naila-Jean Meyers',
#  'Vanessa Friedman, Maggie Haberman and Alan Rappeport',
#  'David Waldstein and Ben Rothenberg',
#  'Michael Wines and Jess Bidgood',
#  'Aurelien Breeden',
#  'Geeta Anand and Julfikar Ali Manik',
#  'Benjamin Weiser',
#  'Andrea Kannapell and David Scull',
#  'Eric Lipton and Adam Liptak',
#  'Mark Scott',
#  'James Delingpole',
#  'Milo',
#  'Adam Nagourney',
#  'Robert Simonson',
#  'Richard Goldstein',
#  'Javier C. Hernández',
#  'Jon Mooallem',
#  'Liz Spayd with Evan Gershkovich',
#  'Michael M. Grynbaum',
#  'Prashant S. Rao and Sewell Chan',
#  'Adam Liptak and Michael D. Shear',
#  'Bob Price and John Binder',
#  'Adam Nagourney and Jennifer Medina',
#  'Stacy Cowley',
#  'Winnie Hu',
#  'Hiroko Tabuchi',
#  'Annie Stoltie',
#  'Daniel E. Slotnik',
#  'Tim Arango and Ceylan Yeginsu',
#  'Adam Liptak',
#  'Rebecca R. Ruiz',
#  'Nicholas Lemann',
#  'Helene Cooper and Eric Schmitt',
#  'Mujib Mashal and Taimoor Shah',
#  'Nick Hallett',
#  'Allum Bokhari',
#  'Bruce Feiler',
#  'Alexander Burns and Thomas Kaplan',
#  'Michael Paulson and Michael Barbaro',
#  'Karoline Kan',
#  'George Gene Gustines',
#  'Kai Schultz and Rajneesh Bhandari',
#  'Azam Ahmed',
#  'Lizette Alvarez and Nick Madigan',
#  'Kevin Quealy and Margot Sanger-Katz',
#  'Sam Borden',
#  'Neil MacFarquhar',
#  'Mike Isaac and Michael J. de la Merced',
#  'Sheri Fink',
#  'Michael Cooper',
#  'Amy Harmon',
#  'Ron Nixon and Maggie Haberman',
#  'Erin McCann',
#  'Kirk Semple',
#  'Jessica Bennett',
#  'Landon Thomas Jr., Liz Alderman and Aurelien Breeden',
#  'Eli Rosenberg',
#  'Charlie Savage, Eric Lipton, Gardiner Harris and Michael D. Shear',
#  'Julie Bosman',
#  'Nicholas Kulish, Caitlin Dickerson and Ron Nixon',
#  'Julie Hirschfeld Davis and Frances Robles',
#  'Neil MacFarquhar and David E. Sanger',
#  'Breitbart TV',
#  'John Schwartz',
#  'Tammy La Gorce',
#  'Rachel Donadio and Liam Stack',
#  'Ben Sisario',
#  'Michiko Kakutani',
#  'Andy Newman',
#  'Michael R. Gordon and Tim Arango',
#  'Kathryn Shattuck',
#  'Nicholas Confessore',
#  'Bill Vlasic',
#  'Michael Corkery and Michael Wines',
#  'Nate Cohn and Toni Monkovic',
#  'Ivan Nechepurenko and Neil MacFarquhar',
#  'Matt Flegenheimer and Yamiche Alcindor',
#  'Julia Wallace',
#  'Perri Klass, M.D.',
#  'Michael S. Schmidt and Eric Schmitt',
#  'Daniel Politi',
#  'Alison Smale and James Kanter',
#  'Ashley Parker and Alexander Burns',
#  'William Neuman',
#  'Julie Hirschfeld Davis and Alan Rappeport',
#  'Daniel Leberfeld',
#  'Helene Cooper and Peter Baker',
#  'Alan Blinder, Niraj Chokshi and Richard Pérez-Peña',
#  'Anne Barnard, Hwaida Saad and Ben Hubbard',
#  'Peter Baker and Somini Sengupta',
#  'Mark Landler and Jane Perlez',
#  'Nida Najar and Hari Kumar',
#  'Salman Masood',
#  'Gaia Pianigiani',
#  'Penelope Green',
#  'Lizette Alvarez and Niraj Chokshi',
#  'Glenn Thrush and Maggie Haberman',
#  'Wendy Lyons Sunshine',
#  'Logan Churchwell',
#  'Frances Robles',
#  'Ben Ratliff',
#  'Su-Hyun Lee and Paul Mozur',
#  'Eli Rosenberg and Emily Palmer',
#  'Eric Lipton, Matthew Rosenberg and Nicholas Fandos',
#  'Anne Barnard and Hwaida Saad',
#  'Eric Lipton and Coral Davenport',
#  'Kristen Scharold',
#  'Michael R. Gordon and Eric Schmitt',
#  'Susan Dynarski',
#  'Donald G. McNeil Jr.',
#  'Somini Sengupta and Rick Gladstone',
#  'Julie Hirschfeld Davis and Charlie Savage',
#  'Michael Paulson and David Gelles',
#  'Cecilia Kang',
#  'Alan Rappeport and Matt Flegenheimer',
#  'Scott Shane',
#  'Karen Workman and David Scull',
#  'Tim McKeough',
#  'David E. Sanger and William J. Broad',
#  'Pete Wells',
#  'Seth Berkman',
#  'Emily Badger',
#  'Anna Dubenko and Michelle L. Dozois',
#  'Ann Coulter',
#  'Ben Brantley',
#  'Adam Nagourney and Ian Lovett',
#  'Joe Nocera',
#  'Liz Robbins',
#  'Ron Nixon',
#  'Dave Philipps',
#  'John Eligon and Serge F. Kovaleski',
#  'Breitbart News, Amanda House',
#  'Marc Santora and Samantha Schmidt',
#  'Laurie Goodstein and Anemona Hartocollis',
#  'Patricia Cohen',
#  'Kenneth R. Rosen',
#  'Daphne Matziaraki',
#  'Andrea Kannapell and Erica Ackerberg',
#  'Mark Landler and Mark Mazzetti',
#  'Hiroko Tabuchi and Neal E. Boudette',
#  'Chris Buckley and Adam Wu',
#  'Danny Hakim',
#  'Joseph Goldstein',
#  'Rory Smith',
#  'Brandon Darby',
#  'Nicholas Bakalar',
#  'Courtney Rubin',
#  'Marjorie Dannenfelser',
#  'Matt Flegenheimer and Scott Shane',
#  'Thomas Kaplan',
#  'Christopher Clarey',
#  'Chris Buckley',
#  'Mark Mazzetti, Anne Barnard and Eric Schmitt',
#  'Alison Smale',
#  'Gretchen Morgenson',
#  'AFP',
#  'Tatiana Schlossberg and John Schwartz',
#  'Nelson D. Schwartz and Michael J. de la Merced',
#  'Pamela Gwyn Kripke',
#  'Joshua Barone',
#  'Amy Chozick',
#  'Kate Zernike',
#  'Adeel Hassan',
#  'Ian Lovett',
#  'The Editorial Board',
#  'Rachel Donadio',
#  'Amie Tsang',
#  'Katrina Onstad',
#  'Andrea Kannapell and Andrew Hinderaker',
#  'Michael S. Schmidt and Noah Weiland',
#  'Jeff Proctor and Fernanda Santos',
#  'James Gorman',
#  'Nina Siegal',
#  'Taras Grescoe',
#  'Malia Wollan',
#  'Vivian Marino',
#  'Michael S. Schmidt and Mark Landler',
#  'Michael D. Shear and Emmarie Huetteman',
#  'AP',
#  'John J. Xenakis',
#  'Alexandra Stevenson and Matthew Goldstein',
#  'Ellen Barry and Suhasini Raj',
#  'Eli Rosenberg and Adam Goldman',
#  'Michael D. Shear and Patrick Healy',
#  'Giulio Meotti (Gatestone Institute)',
#  'Alison Smale and Patrick Kingsley',
#  'Melena Ryzik',
#  'Susanne Craig and Maggie Haberman',
#  'Janet Maslin',
#  'Fernanda Santos',
#  'Patrick Healy and Amy Chozick',
#  'Giovanni Russonello',
#  'Kristin Hussey and Lisa W. Foderaro',
#  'Karen Workman and Jonah Engel Bromwich',
#  'Marc Tracy and Alan Blinder',
#  'Nate Schweber and Lisa W. Foderaro',
#  'Bill Keller',
#  'Gretchen Morgenson and Geraldine Fabrikant',
#  'Katrin Bennhold',
#  'Adam Goldman and Michael S. Schmidt',
#  'Ben Shpigel',
#  'Dan Pringle',
#  'Eric Asimov',
#  'Tim Casey',
#  'Lara Jakes',
#  'Jonathan Martin',
#  'Nicola Clark',
#  'Frances Robles and Julie Turkewitz',
#  'Mike Vorkunov',
#  'Henry Fountain',
#  'Mark Mazzetti',
#  'Maggie Haberman and Kate Zernike',
#  'Thomas Erdbrink and Dan Bilefsky',
#  'Eric Lipton and Maggie Haberman',
#  'Abby Ellin',
#  'Jane E. Brody',
#  'Joyce Lau',
#  'Sheryl Gay Stolberg and Richard Pérez-Peña',
#  'Mekado Murphy',
#  'Ashley Southall',
#  'Kate Murphy',
#  'Andrew Pollack',
#  'Daniel Victor and Erin McCann',
#  'Jodi Kantor',
#  'Brett Sokol',
#  'Gardiner Harris and Melissa Eddy',
#  'Matt Flegenheimer and Michael Barbaro',
#  'Nicholas Casey and Ewan MacKenna',
#  'Emily Palmer',
#  'James Wagner',
#  'David Shaftel',
#  'Julia Preston and Jennifer Medina',
#  'Chris Stein',
#  'Stephen Holden',
#  'Margaret Lyons',
#  'Ken Johnson',
#  'Karen Workman, Karen Zraick and Sandra Stevenson',
#  'Jon Gertner',
#  'Andrew Keh',
#  'Gaia Pianigiani and Elisabetta Povoledo',
#  'Alexander Burns, Jonathan Martin and Maggie Haberman',
#  'Matthew Haag and Richard Fausset',
#  'Peter Baker and Steven Erlanger',
#  'Adam Goldman, Hiroko Tabuchi and Jack Ewing',
#  'Liz Alderman',
#  'Marianne Rohrlich',
#  'Abby Goodnough and Mitch Smith',
#  'Remy Tumin and Sandra Stevenson',
#  'Noam Scheiber, Maggie Haberman and Glenn Thrush',
#  'Roni Caryn Rabin',
#  'Holland Cotter',
#  'Peter Baker, Maggie Haberman and Glenn Thrush',
#  'Thomas Kaplan and Robert Pear',
#  'Assemblyman Tim Donnelly',
#  'Daniel Nussbaum &amp Jerome Hudson',
#  'Maggie Haberman, Jeremy W. Peters and Peter Baker',
#  'Liam Stack and Jess Bidgood',
#  'Julie Weed',
#  'Richard C. Paddock',
#  'Richard B. Woodward',
#  'Jacqueline Williams',
#  'Jack Ewing, Adam Goldman and Hiroko Tabuchi',
#  'Adam Nossiter',
#  'Benjamin Weiser and Maggie Haberman',
#  'Helene Cooper and David E. Sanger',
#  'Raheem Kassam',
#  'Abby Goodnough',
#  'Michael D. Shear and Ron Nixon',
#  'Alan Feuer',
#  'Ali Waked',
#  'Hayley Phelan',
#  'Mireya Navarro',
#  'Timothy Williams and Caitlin Dickerson',
#  'Peter Baker and Declan Walsh',
#  'Jackie Calmes',
#  'Richard Pérez-Peña and Jon Hurdle',
#  'Emmarie Huetteman',
#  'Alan Rappeport and Noah Weiland',
#  'Sheryl Gay Stolberg and Denise Grady',
#  'Matt Richtel and Andrew Pollack',
#  'James Kanter',
#  'Tim Arango and Falih Hassan',
#  'John Branch',
#  'Amy Chozick and Megan Thee-Brenan',
#  'Jennifer Steinhauer and Robert Pear',
#  'Emma G. Fitzsimmons and Noah Remnick',
#  'Nicola Clark and Liam Stack',
#  'Chad Bray',
#  'Mitch Smith',
#  'Ron Lieber',
#  'Maggie Haberman and Nicholas Fandos',
#  'Matthew Goldstein',
#  'Wendy Lesser',
#  'Campbell Robertson',
#  'William K. Rashbaum',
#  'Gal Beckerman',
#  'Mark Mazzetti and Eric Schmitt',
#  'Jonathan Wolfe',
#  'Christopher Mele and Eli Rosenberg',
#  'Jonah Bromwich and Sandra Stevenson',
#  'Peter Baker and Isabel Kershner',
#  'Eric Lichtblau and Steven Lee Myers',
#  'Raphael Minder',
#  'Michael Barbaro, Ashley Parker and Amy Chozick',
#  'Sui-Lee Wee',
#  'Sridhar Pappu',
#  'Cecilia Kang and Katie Benner',
#  'Daniel Victor and Sandra Stevenson',
#  'Ruth La Ferla',
#  'Anne Bayefsky',
#  'David W. Dunlap',
#  'Marc Tracy, Zach Schonbrun and Victor Mather',
#  'Alexis Soloski and Erik Piepenburg',
#  'Alan Rappeport and Eric Lichtblau',
#  'Bob Price and Ildefonso Ortiz',
#  'Jack Hadfield',
#  'Matthew Muspratt',
#  'Ken Belson, Richard Sandomir and Rory Smith',
#  'Rachel Rabkin Peachman',
#  'Magdy Samaan and Declan Walsh',
#  'Simon Romero and Daniel Politi',
#  'Michael Schwirtz and Michael Winerip',
#  'Richard C. Paddock, Eric Lipton, Ellen Barry, Rod Nordland, Danny Hakim and Simon Romero',
#  'Rick Lyman',
#  'Sean Alfano',
#  'Ann Carrns',
#  'Choe Sang-Hun and Richard C. Paddock',
#  'Bryan Denton',
#  'Simon Romero and Nicholas Casey',
#  'Thomas Erdbrink',
#  'Josh Keller and Adam Pearce',
#  'Jonathan Martin and Maggie Haberman',
#  'Dana Goldstein',
#  'Richard A. Oppel Jr. and Richard Pérez-Peña',
#  'Richard Pérez-Peña and Adam Goldman',
#  'Jo Becker and Matthew Rosenberg',
#  'Gerry Mullany and Chris Buckley',
#  'Thomas Erdbrink and Rachel Donadio',
#  'Robert D. McFadden',
#  'Ginia Bellafante',
#  'Amy Chozick, Nicholas Confessore, Steve Eder, Yamiche Alcindor and Farah Stockman',
#  'Matt Apuzzo',
#  'Kit Eaton',
#  'Corey Kilgannon',
#  'Denise Grady',
#  'Emily Steel',
#  'Jo Becker, Adam Goldman, Michael S. Schmidt and Matt Apuzzo',
#  'Lily Brooks-Dalton',
#  'Steven Erlanger, Stephen Castle and Sewell Chan',
#  'Ana Marie Cox',
#  'Anne Barnard and Michael R. Gordon',
#  'Saeed Al-Batati',
#  'Joe Cochrane',
#  'Amy Chozick and Patrick Healy',
#  'Jonathan Soble and Michael J. de la Merced',
#  'Stephanie Strom',
#  'Leslie Picker',
#  'Amy Chozick and Mark Landler',
#  'Frances Robles and Timothy Williams',
#  'Steven Lee Myers',
#  'Hassan Moosa and Geeta Anand',
#  'Natalie Angier',
#  'Jim Farber',
#  'Geeta Anand',
#  'Shaila Dewan and Andrew W. Lehren',
#  'David E. Sanger and Michael Corkery',
#  'Tatiana Schlossberg',
#  'Julie Hirschfeld Davis and Nicholas Fandos',
#  'Hilary Howard',
#  'Ray Glier',
#  'Sheryl Gay Stolberg and Erik Eckholm',
#  'Jeannie Ralston',
#  'Jerry Garrett',
#  'Brian McNicoll',
#  'Julia Moskin',
#  'Tamara Best',
#  'Michael Barbaro and Monica Davey',
#  'Jaime Yaya Barry',
#  'Amanda Taub and Max Fisher',
#  'Alan Blinder and Alan Feuer',
#  'Quoctrung Bui',
#  'Sen. Rand Paul (R-KY)',
#  'David E. Sanger and Nicole Perlroth',
#  'Sheryl Gay Stolberg, Julie Bosman, Manny Fernandez and Julie Hirschfeld Davis',
#  'Jenna Wortham, Amanda Hess and Margaret Lyons',
#  'Michael R. Gordon',
#  'Anthony Kohrs &amp Robert Coleman',
#  'Alexander Burns, Binyamin Appelbaum and Neil Irwin',
#  'Lizette Alvarez and Pam Belluck',
#  'JoAnna Klein',
#  'Alexandra Stevenson',
#  'Jennifer Steinhauer and Thomas Kaplan',
#  'Brandon Darby &amp Ildefonso Ortiz',
#  'Kyle DeNuccio',
#  'Nelson D. Schwartz',
#  'Guy Trebay and Jacob Bernstein',
#  'William J. Broad',
#  'Anthony Tommasini',
#  'Michael Schwirtz and Chris Dixon',
#  'Ashley Parker and Maggie Haberman',
#  'Vivian Yee and Jesse McKinley',
#  'Elizabeth Olson',
#  'Wesley Morris and Jenna Wortham',
#  'Billy Witz',
#  'Elizabeth A. Harris',
#  'Ivan Nechepurenko',
#  'Reuters',
#  'Les Neuhaus',
#  'Zach Wichter',
#  'Mitch Smith and Richard Pérez-Peña',
#  'Laura M. Holson',
#  'Abby Goodnough and Jonathan Martin',
#  'Elizabeth Yuko',
#  'Tom Tancredo',
#  'Katie Thomas and Reed Abelson',
#  'Michelle Higgins',
#  'Valeriya Safronova',
#  'David Gelles',
#  'Conor Dougherty and Julie Turkewitz',
#  'Mary Williams Walsh',
#  'Diane Cardwell',
#  'Alexandra Jacobs',
#  'Marie Kondo',
#  'Charles Hurt',
#  'Sharon Otterman',
#  'Karen Workman and Lisa Iaboni',
#  'James Glanz and Rami Nazzal',
#  'Paulina Villegas and Elisabeth Malkin',
#  'Rachel Abrams',
#  'Nicola Clark and Rick Gladstone',
#  'Ian Lovett and Richard Pérez-Peña',
#  'Chris DeRose',
#  'Jo Becker, Matthew Rosenberg and Maggie Haberman',
#  'Samuel Chi',
#  'Julie Hirschfeld Davis and Jonathan Martin',
#  'Yamiche Alcindor and Patrick Healy',
#  'Brooks Barnes and Cara Buckley',
#  'Mikkael A. Sekeres, M.d. and Timothy D. Gilligan, M.d.',
#  'Damon Darlin',
#  'Dan Bilefsky and Henry Fountain',
#  'Sam Sifton',
#  'Alina Tugend',
#  'Anne Barnard and Andrew E. Kramer',
#  'Matt Flegenheimer, Adam Liptak, Carl Hulse and Charlie Savage',
#  'Samin Nosrat',
#  'Florence Fabricant',
#  'Paula Span',
#  'Jacob Bernstein',
#  'Christopher Mele and Annie Correal',
#  'John Herrman',
#  'Alexander Fury',
#  'Jonathan Martin and Matt Flegenheimer',
#  'Chris Dixon and Kevin Sack',
#  'Julfikar Ali Manik and Geeta Anand',
#  'Yotam Ottolenghi',
#  'Christopher Mele, Al Baker and Emily Palmer',
#  'Azam Ahmed and Elisabeth Malkin',
#  'William D. Cohan',
#  'Karen Barrow',
#  'Jack Tonhaben',
#  'Catherine Porter, Dan Levin and Ian Austen',
#  'Jonathan Martin, Maggie Haberman and Amy Chozick',
#  'John Pudner',
#  'Tony Aranda',
#  'Geraldine Fabrikant',
#  'Jonathan Weisman, Emmarie Huetteman and Matt Flegenheimer',
#  'Patrick Kingsley',
#  'Clarissa Sebag-Montefiore',
#  'Scott Shane, Nicholas Confessore and Matthew Rosenberg',
#  'Diaa Hadid',
#  'Scott Tobias',
#  'Dionne Searcey and Jaime Yaya Barry',
#  'Michael D. Shear, Adam Goldman and Emmarie Huetteman',
#  'Alissa J. Rubin and Lilia Blaise',
#  'Norimitsu Onishi and Sewell Chan',
#  'Michael Wines and Manny Fernandez',
#  'John Leland',
#  'Somini Sengupta and Raphael Minder',
#  'Richard Martyn-Hemphill and Joanna Berendt',
#  'Steve Eder and Dave Philipps',
#  'John Otis and Rana F. Sweis',
#  'Stephanie Saul',
#  'David Streitfeld',
#  'Emily Bobrow',
#  'Stacy Cowley and Matthew Goldstein',
#  'Beverly Gage',
#  'Kerry Hannon',
#  'William C. Rhoden',
#  'Ellen Barry and Nida Najar',
#  'Matthew Brunwasser',
#  'Maggie Haberman and Ashley Parker',
#  'Christopher Drew and Sean D. Naylor',
#  'William Gibson',
#  'Al Baker and J. David Goodman',
#  'Marina Harss',
#  'Azam Ahmed, Paco Nunez and Alan Blinder',
#  'Julie Bosman and Monica Davey',
#  'Balint Bardi and Palko Karasz',
#  'Matthew Rosenberg, Maggie Haberman and Eric Schmitt',
#  'Simon Romero and Vinod Sreeharsha',
#  'Danielle Brooks',
#  'Jodi Kantor and Catrin Einhorn',
#  'Dan Bilefsky',
#  'Jennifer Steinhauer and Emmarie Huetteman',
#  'Alissa J. Rubin and Aurelien Breeden',
#  'Mark Mazzetti and Ben Hubbard',
#  'Kimiko de Freytas-Tamura',
#  'Maggie Haberman and Alan Rappeport',
#  'Seth Kugel',
#  'Matt Apuzzo and Michael S. Schmidt',
#  'Ashley Ross',
#  'Emily Steel and Michael S. Schmidt',
#  'Miriam Jordan',
#  'James C. McKinley Jr. and Emily Palmer',
#  'Javier C. Hernández and Cao Li',
#  'Jeremy W. Peters and Giovanni Russonello',
#  'Dom Phillips',
#  'Laurie Goodstein',
#  'David M. Herszenhorn',
#  'James C. McKinley Jr.',
#  'Mark Landler and Steven Lee Myers',
#  'Vindu Goel',
#  'Maggy Ayala and Nicholas Casey',
#  'Matt Flegenheimer and Emmarie Huetteman',
#  'Jonathan Mahler',
#  'Alan Feuer and Matt Apuzzo',
#  ...]

# %%
authors_label_1 = set(df[df['label'] == 1]['author'].unique())

authors_label_0 = set(df[df['label'] == 0]['author'].unique())

common_authors = authors_label_1.intersection(authors_label_0)

print("Authors in both label 1 and label 0:")
print(common_authors)
# Out:
# Authors in both label 1 and label 0:
# {nan, 'Pamela Geller', 'Ann Coulter', 'AFP', 'Reuters', 'Pam Key'}
